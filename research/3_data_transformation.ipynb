# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Korisnik\\Desktop\\ml_projects\\ds_resume_light_project\\ds_resume_light_project\\research'

# %%
os.chdir("../")
# %pwd
# Out:
# 'c:\\Users\\Korisnik\\Desktop\\ml_projects\\ds_resume_light_project\\ds_resume_light_project'

# %%
from dataclasses import dataclass
from pathlib import Path

# %%
@dataclass
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.ds_resume_light_project.constants import *
from src.ds_resume_light_project.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:

    def __init__(self, config_filepath = CONFIG_FILE_PATH, params_filepath = PARAMS_FILE_PATH, schema_filepath = SCHEMA_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)
      
        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation
        create_directories([config.root_dir])
        data_transformation_config = DataTransformationConfig(
            root_dir=Path(config.root_dir),
            data_path=Path(config.data_path)
        )

        return data_transformation_config

# %%
import os 
from src.ds_resume_light_project import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config

    def train_test_split(self):
        data = pd.read_csv(self.config.data_path)
        train, test = train_test_split(data, test_size=0.2, random_state=42)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"), index=False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"), index=False)

        logger.info("Data split completed")
        logger.info(f"Train data shape: {train.shape}")
        logger.info(f"Test data shape: {test.shape}")

# %%
try:
    config_manager = ConfigurationManager()
    data_transformation_config = config_manager.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_split()
except Exception as e:
    raise e
# Out:
# [2026-01-25 19:52:01,161: INFO: common]: YAML file: config\config.yaml loaded successfully
# [2026-01-25 19:52:01,167: INFO: common]: YAML file: params.yaml loaded successfully
# [2026-01-25 19:52:01,181: INFO: common]: YAML file: schema.yaml loaded successfully
# [2026-01-25 19:52:01,184: INFO: common]: Directory created at: artifacts
# [2026-01-25 19:52:01,186: INFO: common]: Directory created at: artifacts/data_transformation
# [2026-01-25 19:52:01,230: INFO: 159225224]: Data split completed
# [2026-01-25 19:52:01,231: INFO: 159225224]: Train data shape: (1279, 12)
# [2026-01-25 19:52:01,231: INFO: 159225224]: Test data shape: (320, 12)
